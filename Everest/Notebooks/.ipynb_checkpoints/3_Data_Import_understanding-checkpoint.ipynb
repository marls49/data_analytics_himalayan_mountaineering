# %% [markdown]
# The dataset was, following the work done in 2_Data_Collection shared within the team so that everyone was working off the same dataset. A couple of checks using head() were conducted as a test for consistency which passeed.

# %%
import pandas as pd
import numpy as np

expeddf = pd.read_csv("himalayan_tidy/expeddf_tidy.csv", low_memory=False)
peaksdf = pd.read_csv("himalayan_tidy/peaksdf_tidy.csv", low_memory=False)

expeddf.head(10)
# Out:
#        EXPID PEAKID  YEAR  SEASON  HOST              ROUTE1  \
# 0  ANN260101   ANN2  1960       1     1    NW Ridge-W Ridge
# 1  ANN269301   ANN2  1969       3     1    NW Ridge-W Ridge
# 2  ANN273101   ANN2  1973       1     1      W Ridge-N Face
# 3  ANN278301   ANN2  1978       3     1      N Face-W Ridge
# 4  ANN279301   ANN2  1979       3     1      N Face-W Ridge
# 5  ANN280101   ANN2  1980       1     1      N Face-W Ridge
# 6  ANN280102   ANN2  1980       1     1  SE Spur (to 6000m)
# 7  ANN281302   ANN2  1981       3     1    NW Ridge-W Ridge
# 8  ANN281301   ANN2  1981       3     1     S Ridge/SE Face
# 9  ANN282301   ANN2  1982       3     1              S Face
#
#                       ROUTE2 ROUTE3 ROUTE4      NATION  ...  \
# 0                        NaN    NaN    NaN          UK  ...
# 1                        NaN    NaN    NaN  Yugoslavia  ...
# 2                        NaN    NaN    NaN       Japan  ...
# 3                        NaN    NaN    NaN          UK  ...
# ...

# %%
peaksdf.head(10)
# Out:
#   PEAKID              PKNAME                     PKNAME2  \
# 0   AMAD          Ama Dablam                Amai Dablang
# 1   AMPG       Amphu Gyabjen               Amphu Gyabien
# 2   ANN1         Annapurna I                         NaN
# 3   ANN2        Annapurna II                         NaN
# 4   ANN3       Annapurna III                         NaN
# 5   ANN4        Annapurna IV                         NaN
# 6   ANNE    Annapurna I East                         NaN
# 7   ANNM  Annapurna I Middle                         NaN
# 8   ANNS     Annapurna South  Annapurna Dakshin, Moditse
# 9   APIM            Api Main                         NaN
#
#                                       LOCATION  HEIGHTM  HEIGHTF  HIMAL  \
# 0                                 Khumbu Himal     6814    22356     12
# 1               Khumbu Himal (N of Ama Dablam)     5630    18471     12
# 2                              Annapurna Himal     8091    26545      1
# ...

# %% [markdown]
# Data Dictionary can be found here; https://github.com/rfordatascience/tidytuesday/blob/main/data/2025/2025-01-21/readme.md.

# %% [markdown]
# **Dictionary exped.csv.**
#
# | Variable           | Class      | Description                                         |
# |--------------------|------------|-----------------------------------------------------|
# | EXPID              | factor     | Expedition ID.                                      |
# | PEAKID             | factor     | Peak ID                                             |
# | YEAR               | factor     | Year of the expedition.                             |
# | SEASON             | integer    | Season of the expedition as an integer.             |
# | SEASON_FACTOR      | character  | Season as descriptive name.                         |
# | HOST               | integer    | Host country as an integer.                         |
# | HOST_FACTOR        | character  | Host country as descriptive name.                   |
# | ROUTE1             | factor     | Climbing route 1.                                   |
# | ROUTE2             | factor     | Climbing route 2.                                   |
# | ROUTE3             | factor     | Climbing route 3.                                   |
# | ROUTE4             | factor     | Climbing route 4.                                   |
# | NATION             | factor     | Principle nationality.                              |
# | LEADERS            | factor     | Leadership of the expedition.                       |
# | SPONSOR            | factor     | Expedition sponsor / name.                          |
# | SUCCESS1           | logical    | Success on route 1?                                 |
# | SUCCESS2           | logical    | Success on route 2?                                 |
# | SUCCESS3           | logical    | Success on route 3?                                 |
# | SUCCESS4           | logical    | Success on route 4?                                 |
# | ASCENT1            | factor     | Ascent numbers for route 1.                         |
# | ASCENT2            | factor     | Ascent numbers for route 2.                         |
# | ASCENT3            | factor     | Ascent numbers for route 3.                         |
# | ASCENT4            | factor     | Ascent numbers for route 4.                         |
# | CLAIMED            | logical    | Success claimed?                                    |
# | DISPUTED           | logical    | Success disputed?                                   |
# | COUNTRIES          | factor     | Other countries.                                    |
# | APPROACH           | factor     | Approach march.                                     |
# | BCDATE             | date       | Date arrived at base camp.                          |
# | SMTDATE            | date       | Date reached summit.                                |
# | SMTTIME            | factor     | Time reached summit.                                |
# | SMTDAYS            | integer    | Number of days to summit / high-point.              |
# | TOTDAYS            | integer    | Total number of days.                               |
# | TERMDATE           | date       | Date expedition was terminated.                     |
# | TERMREASON         | integer    | Termination reason as integer.                      |
# | TERMREASON_FACTOR  | character  | Termination reason as descriptive name.             |
# | TERMNOTE           | factor     | Termination details.                                |
# | HIGHPOINT          | integer    | Expedition high-point.                              |
# | TRAVERSE           | logical    | Expedition traversed?                               |
# | SKI                | logical    | Ski / snowboard descent?                            |
# | PARAPENTE          | logical    | Parapente descent?                                  |
# | CAMPS              | integer    | Number of high camps above base camp.               |
# | ROPE               | integer    | Amount of fixed rope.                               |
# | TOTMEMBERS         | integer    | Number of members.                                  |
# | SMTMEMBERS         | integer    | Members on summit.                                  |
# | MDEATHS            | integer    | Number of member deaths.                            |
# | TOTHIRED           | integer    | Hired personnel above base camp.                    |
# | SMTHIRED           | integer    | Hired personnel on summit.                          |
# | HDEATHS            | integer    | Hired personnel deaths.                             |
# | NOHIRED            | logical    | No hired personnel used above base camp.            |
# | O2USED             | logical    | Oxygen used?                                        |
# | O2NONE             | logical    | Oxygen not used?                                    |
# | O2CLIMB            | logical    | Oxygen climbing?                                    |
# | O2DESCENT          | logical    | Oxygen descending?                                  |
# | O2SLEEP            | logical    | Oxygen sleeping?                                    |
# | O2MEDICAL          | logical    | Oxygen used medically?                              |
# | O2TAKEN            | logical    | Oxygen taken, not used?                             |
# | O2UNKWN            | logical    | Oxygen use unknown?                                 |
# | OTHERSMTS          | factor     | Other summits.                                      |
# | CAMPSITES          | factor     | Campsite details.                                   |
# | ROUTEMEMO          | factor     | Route details.                                      |
# | ACCIDENTS          | factor     | Accidents on the expedition.                        |
# | ACHIEVMENT         | factor     | Achievements.                                       |
# | AGENCY             | factor     | Trekking agency.                                    |
# | COMRTE             | logical    | Commercial route?                                   |
# | STDRTE             | logical    | 8000m standard route?                               |
# | PRIMRTE            | logical    | Info with primary expedition?                       |
# | PRIMMEM            | logical    | Member info with primary expedition?                |
# | PRIMREF            | logical    | Literature info with primary expedition?            |
# | PRIMID             | factor     | Primary expedition ID (if any).                     |
# | CHKSUM             | integer    | Internal consistency check.                         |

# %% [markdown]
# Dictionary peaks.csv
#
# | Variable       | Class      | Description                                                           |
# |----------------|-----------|-----------------------------------------------------------------------|
# | PEAKID         | integer   | Peak ID, the key field (unique identifier) for each record.           |
# | PKNAME         | integer   | Peak name.                                                            |
# | PKNAME2        | integer   | Peak name 2.                                                          |
# | LOCATION       | integer   | Location of the peak.                                                 |
# | HEIGHTM        | integer   | Peak height in meters.                                                |
# | HEIGHTF        | integer   | Peak height in feet.                                                  |
# | HIMAL          | integer   | Mountain range identifier; see HIMAL_FACTOR for names.                |
# | HIMAL_FACTOR   | integer   | Mountain range name.                                                  |
# | REGION         | integer   | Region identifier.                                                    |
# | REGION_FACTOR  | string    | Region name.                                                          |
# | OPEN           | bool      | Indicates peak is open for expeditions.                               |
# | UNLISTED       | bool      | Indicates peak is unlisted in official records.                       |
# | TREKKING       | bool      | Indicates peak is a trekking peak.                                    |
# | TREKYEAR       | integer   | Year the peak was designated as a trekking peak.                      |
# | RESTRICT       | bool      | Peak is restricted for climbing or access.                            |
# | PHOST          | integer   | Primary host country identifier; see PHOST_FACTOR for names.          |
# | PHOST_FACTOR   | string    | Primary host country name for PHOST.                                  |
# | PSTATUS        | integer   | Climbing status identifier; see PSTATUS_FACTOR for names.             |
# | PSTATUS_FACTOR | string    | Climbing status description for PSTATUS.                              |
# | PEAKMEMO       | string    | Additional notes/remarks about the peak.                              |
# | PYEAR          | integer   | Year of first recorded climbing attempt.                              |
# | PSEASON        | string    | Climbing season associated with first ascent/expedition.              |
# | PEXPID         | integer   | Expedition ID for first recorded climb.                               |
# | PSMTDATE       | string    | Date of first successful summit.                                      |
# | PCOUNTRY       | string    | Country of origin for the expedition or climbers.                     |
# | PSUMMITERS     | integer   | Number of climbers who first reached summit.                          |
# | PSMTNOTE       | string    | Notes related to first successful summit.                             |
# | REFERMEMO      | string    | Peak chronology references.                                           |
# | PHOTOMEMO      | string    | Peak photo references.                                                |

# %% [markdown]
# Having reviewed peaksdf decided to remove the following columns from the table; HEIGHTF, UNLISTED, TREKKING, and TREKYEAR based on the focus of the questions agreed in the Abgabe.
#
# 1. What is the distribution of climbing status (PSTATUS) across different mountain ranges (HIMAL_FACTOR)?
# 2. Which mountain range (HIMAL_FACTOR) has the highest average peak height (HEIGHTM)?
# 3. What is the distribution of peak heights (HEIGHTM) for peaks that are open (OPEN) versus those that are not?
# 4. Which climbing routes (ROUTE1, ROUTE2, ROUTE3, ROUTE4) have the highest success rates (SUCCESS1, SUCCESS2, SUCCESS3, SUCCESS4) across all expeditions?
# 5. How does the use of supplemental oxygen (O2USED, O2NONE) affect summit success rates?
# 6. How often does bad weather (TERMREASON = 4) play a role in termination compared to technical difficulty (TERMREASON = 10)?
# 7. Are expeditions with no hired personnel (NOHIRED) associated with higher or lower death rates?

# %%
peaksdf = peaksdf.drop(columns = ["HEIGHTF", "UNLISTED", "TREKKING", "TREKYEAR"])

# %%
peaksdf
# Out:
#     PEAKID                PKNAME          PKNAME2  \
# 0     AMAD            Ama Dablam     Amai Dablang
# 1     AMPG         Amphu Gyabjen    Amphu Gyabien
# 2     ANN1           Annapurna I              NaN
# 3     ANN2          Annapurna II              NaN
# 4     ANN3         Annapurna III              NaN
# ..     ...                   ...              ...
# 485   MAHA           Mahalanagur              NaN
# 486   CHWE             Chaw East              NaN
# 487   PTHN  Pathibhara Northeast  Pathibhara East
# 488   PTHS  Pathibhara Southeast              NaN
# 489   CHNK         Changla Khang              NaN
#
#                                               LOCATION  HEIGHTM  HIMAL  \
# 0                                         Khumbu Himal     6814     12
# 1                       Khumbu Himal (N of Ama Dablam)     5630     12
# 2                                      Annapurna Himal     8091      1
# 3                                      Annapurna Himal     7937      1
# ...
