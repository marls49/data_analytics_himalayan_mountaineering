# %% [markdown]
# Data source: https://github.com/rfordatascience/tidytuesday/blob/main/data/2025/2025-01-21/exped_tidy.csv
#
# Pandas Data was downloaded from github and then panda was used to create a DataFrame on pandas.
#
# The first step was to change the data from UTF 16 - UTF 8 due to the preferance of the IOS

# %%
import pandas as pd

df = pd.read_csv('exped_tidy.csv', encoding='latin1')  
df.to_csv('exped_tidy_utf8.csv', index=False, encoding='utf-8')

# %% [markdown]
# ***Initial cleaning***
#
# in order to analysis how clean the tidy data was several checks were then performed on the data.
#
# 1. First column SMTDays (Summit Days) remove NaN or 0 values
#
# *Results*
# Name: SMTDAYS, Length: 394, dtype: int64
# Number of changed cells: 25637
#
#
#
# Conclusion: not clean up was necessary so decided to download the raw data.

# %%
import pandas as pd

df = pd.read_csv('../OLD/Data/exped_tidy_utf8.csv')
df_original = df.copy()

#convert SMTDAYS to numeric, erros coerce to NaN (removes non numbers)
df['SMTDAYS'] = pd.to_numeric(df['SMTDAYS'], errors ='coerce')

#remove rows where SMTDAYS is NaN or 0
df_clean = df[(~df['SMTDAYS'].isna()) & (df['SMTDAYS']!=0)]

print(df_clean['SMTDAYS'])

#compare with original 
df_clean_aligned = df_clean.reindex(df_original.index)
comparison = df_original.compare(df_clean_aligned)
num_changed = comparison.notna().sum().sum()
print(f"Number of changed cells: {num_changed}")
# Out:
# 2      35
# 3       1
# 4       9
# 5      16
# 6      11
#        ..
# 852     8
# 868    28
# 877     3
# 880     2
# 881    18
# Name: SMTDAYS, Length: 394, dtype: int64
# Number of changed cells: 25637

# %% [markdown]
# 2. Second test was all of the colonms in data set
#
# Results: Number of changed cells: 47897

# %%
import pandas as pd

#Read the CSV file 
df = pd.read_csv('../OLD/Data/exped_tidy_utf8.csv')
df_original = df.copy()

#All columns to numeric, non-numeric becomes NaN
df_numeric = df.apply(pd.to_numeric, errors='coerce')

# Remove rows where value is NaN or 0 
df_clean = df_numeric.dropna()
df_clean = df_clean[(df_clean != 0).all(axis=1)]

#compare with original 
df_clean_aligned = df_clean.reindex(df_original.index)
comparison = df_original.compare(df_clean_aligned)
num_changed = comparison.notna().sum().sum()

print(f"Number of changed cells: {num_changed} ")
# Out:
# Number of changed cells: 47897

# %% [markdown]
# **Review of the original data set**
#
# Then downloaded the original dataset from himalayandatabase.com/index.html and downloaded zip file from the website.
#
# The

# %%
import plotly.express as px

fig = px.histogram(df, x="YEAR")
fig.show()

# %%
df
# Out:
#          EXPID PEAKID  YEAR  SEASON SEASON_FACTOR  HOST HOST_FACTOR  \
# 0    EVER20101   EVER  2020       1        Spring     2       China
# 1    EVER20102   EVER  2020       1        Spring     2       China
# 2    EVER20103   EVER  2020       1        Spring     2       China
# 3    AMAD20301   AMAD  2020       3        Autumn     1       Nepal
# 4    AMAD20302   AMAD  2020       3        Autumn     1       Nepal
# ..         ...    ...   ...     ...           ...   ...         ...
# 877  PATR24201   PATR  2024       2        Summer     1       Nepal
# 878  PUMO24101   PUMO  2024       1        Spring     1       Nepal
# 879  PUTH24101   PUTH  2024       1        Spring     1       Nepal
# 880  TKPO24101   TKPO  2024       1        Spring     1       Nepal
# 881  YLNG24101   YLNG  2024       1        Spring     1       Nepal
#
#              ROUTE1 ROUTE2  ROUTE3  ...  ACCIDENTS ACHIEVMENT  \
# 0    N Col-NE Ridge    NaN     NaN  ...        NaN        NaN
# 1    N Col-NE Ridge    NaN     NaN  ...        NaN        NaN
# 2    N Col-NE Ridge    NaN     NaN  ...        NaN        NaN
# 3          SW Ridge    NaN     NaN  ...        NaN        NaN
# 4          SW Ridge    NaN     NaN  ...        NaN        NaN
# ..              ...    ...     ...  ...        ...        ...
# 877        NW Ridge    NaN     NaN  ...        NaN        NaN
# 878         SE Face    NaN     NaN  ...        NaN        NaN
# 879         NE Face    NaN     NaN  ...        NaN        NaN
# 880         NE Face    NaN     NaN  ...        NaN        NaN
# 881          SE Rib    NaN     NaN  ...        NaN        NaN
#
#                       AGENCY COMRTE  STDRTE  PRIMRTE  PRIMMEM  PRIMREF PRIMID  \
# 0    Holy Mountain Adventure   True    True    False    False    False    NaN
# 1                        NaN   True    True    False    False    False    NaN
# 2    Holy Mountain Adventure   True    True    False    False    False    NaN
# 3         Seven Summit Treks   True   False    False    False    False    NaN
# 4           Himalayan Guides   True   False    False    False    False    NaN
# ..                       ...    ...     ...      ...      ...      ...    ...
# 877                      NaN  False   False    False    False    False    NaN
# 878           Asian Trekking  False   False    False    False    False    NaN
# 879   Holiday Himalaya Treks  False   False    False    False    False    NaN
# 880              iTrek Nepal  False   False    False    False    False    NaN
# 881         Cho Oyu Trekking  False   False    False    False    False    NaN
#
#       CHKSUM
# 0    2465291
# 1    2465292
# 2    2465293
# 3    2463299
# 4    2463299
# ..       ...
# 877  2463218
# 878     2789
# 879  2463320
# 880  2463393
# 881  2463459
#
# [882 rows x 69 columns]
